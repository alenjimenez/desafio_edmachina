# %% [markdown]
# # **DESAFÍO ED MACHINA**
# Alen Jiménez - Febrero 2024

# %% [markdown]
# **MACHINE LEARNING (ML)**

# %% [markdown]
# El objetivo de esta notebook es presentar modelos de aprendizaje automático que nos ayuden a predecir si un alumno va a aprobar un curso.

# %% [markdown]
# # Tabla de Contenidos
# * 0. [Set Up General](#set_up_general)
# * 1. [Procesamiento preparatorio para aprendizaje automático](#procesamiento)
# * 2. [Machine Learning: Preselección de modelos](#ml_preseleccion)
# * 3. [Machine Learning: Procesamiento de Modelos](#ml_procesamiento_modelos)

# %%
# Importamos bibliotecas

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import bokeh
import altair as alt
import re
import scipy
import warnings
from collections import Counter

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,\
    recall_score, precision_score, f1_score, roc_auc_score,\
        classification_report, precision_recall_curve, auc

from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.neighbors import NearestCentroid
from sklearn.naive_bayes import BernoulliNB

from xgboost import XGBClassifier # Clasificador de XGBoost
from bayes_opt import BayesianOptimization # Optimización Bayesiana

import lazypredict
from lazypredict.Supervised import LazyRegressor
from lazypredict.Supervised import LazyClassifier

pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

# %%
# Directorio de trabajo

directorio_de_trabajo = 'C:/Users/alenj/Escritorio/proyectos/desafio_edmachina'

os.chdir(directorio_de_trabajo)

print(f'Directorio actual de trabajo: {os.getcwd()}')
# Out:
# Directorio actual de trabajo: C:\Users\alenj\Escritorio\proyectos\desafio_edmachina

# %%
# Importamos el csv

df = pd.read_csv('output/output_dw.csv', sep = ',', encoding = 'utf-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2638 entries, 0 to 2637
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        2638 non-null   int64
#  1   user_uuid                 2638 non-null   object
#  2   periodo                   2638 non-null   int64
#  3   course_uuid               2638 non-null   object
#  4   dias_hasta_primer_examen  2638 non-null   float64
#  5   semestre_2                2638 non-null   int64
#  6   aprobo                    2638 non-null   int64
#  7   nota_parcial              2638 non-null   float64
#  8   score                     2479 non-null   float64
#  9   tiempo_hasta_submision    2417 non-null   float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 206.2+ KB

# %% [markdown]
# # 1. Procesamiento preparatorio para aprendizaje automático <a class = 'anchor' id = 'procesamiento'></a>

# %% [markdown]
# Vemos que hay algunos valores faltantes en score y tiempo_hasta_submision. Los completamos con el promedio.

# %%
# Completamos valores faltantes

score_mean = df['score'].mean()
tiempo_mean = df['tiempo_hasta_submision'].mean()

df['score'].fillna(score_mean, inplace=True)
df['tiempo_hasta_submision'].fillna(tiempo_mean, inplace=True)

# %%
# Veamos el desbalanceo de clases
 
df['aprobo'].value_counts()
# Out:
# aprobo
# 1    2573
# 0      65
# Name: count, dtype: int64

# %%
# Para fines analíticos, hacemos enroque entre clases

df['desaprobo'] = df['aprobo'].apply(lambda x: 1 if x == 0 else 0)
df['desaprobo'].value_counts()
# Out:
# desaprobo
# 0    2573
# 1      65
# Name: count, dtype: int64

# %%
ratio = df['desaprobo'].value_counts()[0] / df['desaprobo'].value_counts()[1]
ratio
# Out:
# 39.58461538461538

# %% [markdown]
# Hay un ratio de 40:1

# %%
# Dividimos el data frame entre target y features

X = df.drop(columns = ['desaprobo','aprobo','id','user_uuid','periodo','course_uuid','semestre_2']) #semestre_2 es constante
y = df['desaprobo']

# %%
# Dividimos entre train y test

X_train, X_test, y_train, y_test = train_test_split(X, y
                                                    , test_size = 0.3
                                                    , random_state = 41
                                                    , stratify = y)

# %%
# Hacemos oversampling de clase minoritaria usando SMOTE

print('Shape del dataset original %s' % Counter(y_train))

sm = SMOTE(sampling_strategy = 0.5
           , k_neighbors = 5
           , random_state = 0)

X_train_sm, y_train_sm = sm.fit_resample(X_train,y_train)

print('Shape del dataset resample %s' % Counter(y_train_sm))
# Out:
# Shape del dataset original Counter({0: 1801, 1: 45})
# Shape del dataset resample Counter({0: 1801, 1: 900})

# %%
# Estandarizamos

scaler = StandardScaler()  
    
X_train_sc = scaler.fit_transform(X_train) # Estandarizamos los datos     
X_test_sc = scaler.transform(X_test)

X_train_sm_sc = scaler.fit_transform(X_train_sm) # Estandarizamos los datos     
X_test_sm_sc = scaler.transform(X_test)

# %% [markdown]
# # 2. Machine Learning: Preselección de modelos <a class = 'anchor' id = 'ml_preseleccion'></a>

# %%
# Clasificaciones sin resampling

clf0 = LazyClassifier(verbose = 0, ignore_warnings=True, predictions=True, custom_metric = recall_score)
models0, predictions0 = clf0.fit(X_train_sc, X_test_sc, y_train, y_test)
models0
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 23.62it/s]
# [LightGBM] [Info] Number of positive: 45, number of negative: 1801
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 542
# [LightGBM] [Info] Number of data points in the train set: 1846, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.024377 -> initscore=-3.689435
# [LightGBM] [Info] Start training from score -3.689435
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.72               0.74     0.74      0.82
# Perceptron                         0.96               0.57     0.57      0.96
# DecisionTreeClassifier             0.95               0.56     0.56      0.95
# KNeighborsClassifier               0.97               0.52     0.52      0.96
# ExtraTreeClassifier                0.95               0.51     0.51      0.95
# AdaBoostClassifier                 0.97               0.50     0.50      0.96
# LogisticRegression                 0.97               0.50     0.50      0.96
# SVC                                0.97               0.50     0.50      0.96
# SGDClassifier                      0.97               0.50     0.50      0.96
# RidgeClassifierCV                  0.97               0.50     0.50      0.96
# RidgeClassifier                    0.97               0.50     0.50      0.96
# QuadraticDiscriminantAnalysis      0.97               0.50     0.50      0.96
# PassiveAggressiveClassifier        0.97               0.50     0.50      0.96
# LinearSVC                          0.97               0.50     0.50      0.96
# LinearDiscriminantAnalysis         0.97               0.50     0.50      0.96
# GaussianNB                         0.97               0.50     0.50      0.96
# DummyClassifier                    0.97               0.50     0.50      0.96
# CalibratedClassifierCV             0.97               0.50     0.50      0.96
# BernoulliNB                        0.97               0.50     0.50      0.96
# RandomForestClassifier             0.97               0.50     0.50      0.96
# BaggingClassifier                  0.97               0.50     0.50      0.96
# ExtraTreesClassifier               0.97               0.50     0.50      0.96
# LGBMClassifier                     0.97               0.50     0.50      0.96
# XGBClassifier                      0.96               0.49     0.49      0.96
# LabelSpreading                     0.96               0.49     0.49      0.95
# LabelPropagation                   0.95               0.49     0.49      0.95
#
#                                recall_score  Time Taken
# Model
# NearestCentroid                        0.75        0.01
# Perceptron                             0.15        0.00
# DecisionTreeClassifier                 0.15        0.01
# KNeighborsClassifier                   0.05        0.03
# ExtraTreeClassifier                    0.05        0.01
# AdaBoostClassifier                     0.00        0.11
# LogisticRegression                     0.00        0.01
# SVC                                    0.00        0.04
# SGDClassifier                          0.00        0.02
# RidgeClassifierCV                      0.00        0.01
# RidgeClassifier                        0.00        0.01
# QuadraticDiscriminantAnalysis          0.00        0.01
# PassiveAggressiveClassifier            0.00        0.01
# LinearSVC                              0.00        0.03
# LinearDiscriminantAnalysis             0.00        0.01
# GaussianNB                             0.00        0.01
# DummyClassifier                        0.00        0.01
# CalibratedClassifierCV                 0.00        0.03
# BernoulliNB                            0.00        0.01
# RandomForestClassifier                 0.00        0.25
# BaggingClassifier                      0.00        0.05
# ExtraTreesClassifier                   0.00        0.12
# LGBMClassifier                         0.00        0.05
# XGBClassifier                          0.00        0.04
# LabelSpreading                         0.00        0.21
# LabelPropagation                       0.00        0.10

# %% [markdown]
# En términos del Recall Score, NearestCentroid y QuadraticDiscriminantAnalysis son los que mejor performance tienen.

# %%
# Clasificaciones con resampling

clf1 = LazyClassifier(verbose = 0, ignore_warnings=True, predictions=True, custom_metric = recall_score)
models1, predictions1 = clf1.fit(X_train_sm_sc, X_test_sm_sc, y_train_sm, y_test)
models1
# Out:
# 100%|██████████| 29/29 [00:02<00:00, 13.85it/s]
# [LightGBM] [Info] Number of positive: 900, number of negative: 1801
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000067 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 930
# [LightGBM] [Info] Number of data points in the train set: 2701, number of used features: 4
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.333210 -> initscore=-0.693703
# [LightGBM] [Info] Start training from score -0.693703
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# BernoulliNB                        0.70               0.77     0.77      0.80
# PassiveAggressiveClassifier        0.80               0.75     0.75      0.87
# Perceptron                         0.75               0.75     0.75      0.84
# NearestCentroid                    0.76               0.73     0.73      0.84
# QuadraticDiscriminantAnalysis      0.84               0.70     0.70      0.89
# CalibratedClassifierCV             0.85               0.68     0.68      0.90
# LogisticRegression                 0.85               0.68     0.68      0.90
# LinearSVC                          0.85               0.68     0.68      0.90
# RidgeClassifierCV                  0.84               0.68     0.68      0.89
# RidgeClassifier                    0.84               0.68     0.68      0.89
# SGDClassifier                      0.84               0.67     0.67      0.89
# LinearDiscriminantAnalysis         0.84               0.67     0.67      0.89
# GaussianNB                         0.84               0.67     0.67      0.89
# AdaBoostClassifier                 0.92               0.62     0.62      0.94
# NuSVC                              0.86               0.61     0.61      0.90
# KNeighborsClassifier               0.86               0.59     0.59      0.91
# LabelSpreading                     0.88               0.57     0.57      0.91
# ExtraTreeClassifier                0.92               0.57     0.57      0.94
# LabelPropagation                   0.88               0.57     0.57      0.91
# SVC                                0.86               0.56     0.56      0.91
# RandomForestClassifier             0.96               0.54     0.54      0.96
# XGBClassifier                      0.96               0.54     0.54      0.96
# DecisionTreeClassifier             0.94               0.53     0.53      0.94
# LGBMClassifier                     0.96               0.51     0.51      0.95
# ExtraTreesClassifier               0.95               0.51     0.51      0.95
# DummyClassifier                    0.97               0.50     0.50      0.96
# BaggingClassifier                  0.95               0.49     0.49      0.95
#
#                                recall_score  Time Taken
# Model
# BernoulliNB                            0.85        0.01
# PassiveAggressiveClassifier            0.70        0.01
# Perceptron                             0.75        0.01
# NearestCentroid                        0.70        0.01
# QuadraticDiscriminantAnalysis          0.55        0.01
# CalibratedClassifierCV                 0.50        0.03
# LogisticRegression                     0.50        0.01
# LinearSVC                              0.50        0.07
# RidgeClassifierCV                      0.50        0.01
# RidgeClassifier                        0.50        0.01
# SGDClassifier                          0.50        0.01
# LinearDiscriminantAnalysis             0.50        0.01
# GaussianNB                             0.50        0.01
# AdaBoostClassifier                     0.30        0.17
# NuSVC                                  0.35        0.19
# KNeighborsClassifier                   0.30        0.03
# LabelSpreading                         0.25        0.30
# ExtraTreeClassifier                    0.20        0.01
# LabelPropagation                       0.25        0.21
# SVC                                    0.25        0.12
# RandomForestClassifier                 0.10        0.47
# XGBClassifier                          0.10        0.04
# DecisionTreeClassifier                 0.10        0.02
# LGBMClassifier                         0.05        0.04
# ExtraTreesClassifier                   0.05        0.19
# DummyClassifier                        0.00        0.01
# BaggingClassifier                      0.00        0.08

# %% [markdown]
# - Tanto el Balanced Accuracy como el ROC AUC mejoran en casi todos los casos.
# - El Recall mejora en todos los casos, significativamente.
# - BernoulliNB pasa a ser el mejor en general, pero NearestCentroid mantiene una buena performance.

# %% [markdown]
# # 3. Machine Learning: Procesamiento de Modelos <a class = 'anchor' id = 'ml_procesamiento_modelos'></a>

# %%
# Probamos con BernoulliNB

def bernoulliNB_report(X_train,X_test,y_train,y_test):

    model=BernoulliNB()
    
    model.fit(X_train,y_train)
    y_pred=model.predict(X_test)
    y_proba=model.predict_proba(X_test)
    
    print(classification_report(y_test,y_pred))
    
    print('Area bajo la curva ROC:',np.round(roc_auc_score(y_test,y_proba[:,1]),4))
    
    precision, recall,threshold=precision_recall_curve(y_test,y_proba[:,1]);

    print('Area bajo la curva Precision-Recall:',np.round(auc(recall,precision),4))

    return

# %%
bernoulliNB_report(X_train_sm_sc, X_test_sm_sc, y_train_sm, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.69      0.82       772
#            1       0.07      0.85      0.12        20
#
#     accuracy                           0.70       792
#    macro avg       0.53      0.77      0.47       792
# weighted avg       0.97      0.70      0.80       792
#
# Area bajo la curva ROC: 0.7503
# Area bajo la curva Precision-Recall: 0.0498

# %%
# Probamos con XGBClassifier

# Limites inferiores y superiores de los hiperparametros que vamos a optimizar.
pbounds = {
    'learning_rate': (0.01, 1.0),
    'n_estimators': (100, 1000),
    'max_depth': (3,10),
    'subsample': (1.0, 1.0),  # Subsample lo dejamos en 1 que es default para XGBoost ya que no son muchos datos.
    'colsample': (1.0, 1.0),  # Como no hay muchas variables también lo dejamos en uno.
    'gamma': (0, 5)}

# Función de optimización de los hiperparametros
def xgboost_hyper_param(learning_rate,
                        n_estimators,
                        max_depth,
                        subsample,
                        colsample,
                        gamma):
    # Se transforman max_depth y n_estimators en int ya que XGBoost no acepta float.
    max_depth = int(max_depth)
    n_estimators = int(n_estimators)
    
    # Instanciación del XGBClassifier con objetivo multi clasificación
    clf = XGBClassifier(
        max_depth=max_depth,
        learning_rate=learning_rate,
        n_estimators=n_estimators,
        gamma=gamma)
    
    # Retornamos el valor de accuracy obtenido por el modelo
    return np.mean(cross_val_score(clf, X_train_sm_sc, y_train_sm, cv=3, scoring='accuracy'))

# Instanciacion de la optimización bayesiana.
optimizer = BayesianOptimization(
    f=xgboost_hyper_param,
    pbounds=pbounds,
    random_state=1,
)

optimizer.maximize(init_points=20, n_iter=4)

print('Mejor Resultado:', optimizer.max)
# Out:
# |   iter    |  target   | colsample |   gamma   | learni... | max_depth | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------
# | 1         | 0.8978    | 1.0       | 3.602     | 0.01011   | 5.116     | 232.1     | 1.0       |
# | 2         | 0.9471    | 1.0       | 1.728     | 0.4028    | 6.772     | 477.3     | 1.0       |
# | 3         | 0.9278    | 1.0       | 4.391     | 0.03711   | 7.693     | 475.6     | 1.0       |
# | 4         | 0.9478    | 1.0       | 0.9905    | 0.8027    | 9.778     | 382.1     | 1.0       |
# | 5         | 0.9004    | 1.0       | 4.473     | 0.09419   | 3.273     | 252.8     | 1.0       |
# | 6         | 0.9426    | 1.0       | 2.106     | 0.9583    | 6.732     | 722.7     | 1.0       |
# | 7         | 0.9356    | 1.0       | 4.173     | 0.02811   | 8.251     | 990.0     | 1.0       |
# | 8         | 0.9297    | 1.0       | 3.946     | 0.1122    | 6.135     | 917.7     | 1.0       |
# | 9         | 0.9537    | 1.0       | 0.6501    | 0.02917   | 7.752     | 290.5     | 1.0       |
# | 10        | 0.9582    | 1.0       | 0.2668    | 0.5784    | 4.027     | 630.4     | 1.0       |
# | 11        | 0.9363    | 1.0       | 2.07      | 0.6975    | 5.899     | 145.0     | 1.0       |
# | 12        | 0.9397    | 1.0       | 2.574     | 0.9451    | 7.106     | 913.1     | 1.0       |
# | 13        | 0.9178    | 1.0       | 4.037     | 0.4037    | 4.157     | 934.8     | 1.0       |
# | 14        | 0.9334    | 1.0       | 3.63      | 0.8845    | 7.366     | 775.8     | 1.0       |
# | 15        | 0.9311    | 1.0       | 4.479     | 0.4338    | 9.754     | 697.1     | 1.0       |
# | 16        | 0.9304    | 1.0       | 4.747     | 0.4554    | 7.049     | 467.3     | 1.0       |
# | 17        | 0.9363    | 1.0       | 2.868     | 0.01284   | 7.32      | 394.0     | 1.0       |
# | 18        | 0.9437    | 1.0       | 1.786     | 0.9094    | 7.364     | 114.2     | 1.0       |
# | 19        | 0.9015    | 1.0       | 4.987     | 0.1806    | 3.96      | 939.3     | 1.0       |
# | 20        | 0.936     | 1.0       | 3.777     | 0.7563    | 9.461     | 740.4     | 1.0       |
# | 21        | 0.9389    | 1.0       | 2.002     | 0.1051    | 6.815     | 477.2     | 1.0       |
# | 22        | 0.9671    | 1.0       | 0.002572  | 0.2481    | 4.817     | 630.1     | 1.0       |
# | 23        | 0.9567    | 1.0       | 0.3533    | 0.04719   | 5.66      | 629.2     | 1.0       |
# | 24        | 0.9563    | 1.0       | 0.561     | 0.4816    | 5.628     | 630.6     | 1.0       |
# =================================================================================================
# Mejor Resultado: {'target': 0.9670547128704731, 'params': {'colsample': 1.0, 'gamma': 0.0025715444700658008, 'learning_rate': 0.2481491157466493, 'max_depth': 4.81656098379948, 'n_estimators': 630.0610651560637, 'subsample': 1.0}}

# %%
modelo = XGBClassifier(
        max_depth = 5,
        learning_rate=0.2481,
        n_estimators=630,
        gamma=0.003)

modelo.fit(X_train_sm_sc, y_train_sm)

# Predecimos los valores del conjunto de testeo y lo almacenamos en una variable para ver su accuracy
y_pred = modelo.predict(X_test_sm_sc)

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       772
#            1       0.08      0.10      0.09        20
#
#     accuracy                           0.95       792
#    macro avg       0.53      0.53      0.53       792
# weighted avg       0.95      0.95      0.95       792

# %%
# Hacemos una red neuronal muy sencilla

from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 4))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_train_sm_sc, y_train_sm, batch_size=32, epochs=50)
y_pred = np.rint(model.predict(X_test_sm_sc).flatten())
# Out:
# Epoch 1/50
# 85/85 [==============================] - 0s 862us/step - loss: 0.6863 - accuracy: 0.6642
# Epoch 2/50
# 85/85 [==============================] - 0s 831us/step - loss: 0.6622 - accuracy: 0.6668
# Epoch 3/50
# 85/85 [==============================] - 0s 792us/step - loss: 0.6100 - accuracy: 0.6668
# Epoch 4/50
# 85/85 [==============================] - 0s 811us/step - loss: 0.5471 - accuracy: 0.6668
# Epoch 5/50
# 85/85 [==============================] - 0s 831us/step - loss: 0.5069 - accuracy: 0.6668
# Epoch 6/50
# 85/85 [==============================] - 0s 814us/step - loss: 0.4865 - accuracy: 0.6668
# Epoch 7/50
# 85/85 [==============================] - 0s 811us/step - loss: 0.4754 - accuracy: 0.6668
# Epoch 8/50
# 85/85 [==============================] - 0s 825us/step - loss: 0.4684 - accuracy: 0.6668
# Epoch 9/50
# 85/85 [==============================] - 0s 822us/step - loss: 0.4630 - accuracy: 0.6894
# Epoch 10/50
# 85/85 [==============================] - 0s 829us/step - loss: 0.4575 - accuracy: 0.7790
# Epoch 11/50
# 85/85 [==============================] - 0s 1ms/step - loss: 0.4535 - accuracy: 0.7875
# Epoch 12/50
# 85/85 [==============================] - 0s 810us/step - loss: 0.4505 - accuracy: 0.7912
# Epoch 13/50
# 85/85 [==============================] - 0s 791us/step - loss: 0.4484 - accuracy: 0.7960
# Epoch 14/50
# 85/85 [==============================] - 0s 823us/step - loss: 0.4461 - accuracy: 0.7975
# Epoch 15/50
# 85/85 [==============================] - 0s 815us/step - loss: 0.4444 - accuracy: 0.7990
# Epoch 16/50
# 85/85 [==============================] - 0s 827us/step - loss: 0.4431 - accuracy: 0.7997
# Epoch 17/50
# 85/85 [==============================] - 0s 796us/step - loss: 0.4419 - accuracy: 0.8012
# Epoch 18/50
# 85/85 [==============================] - 0s 971us/step - loss: 0.4409 - accuracy: 0.8016
# Epoch 19/50
# 85/85 [==============================] - 0s 809us/step - loss: 0.4401 - accuracy: 0.8012
# Epoch 20/50
# 85/85 [==============================] - 0s 792us/step - loss: 0.4394 - accuracy: 0.8019
# Epoch 21/50
# 85/85 [==============================] - 0s 799us/step - loss: 0.4387 - accuracy: 0.8016
# Epoch 22/50
# 85/85 [==============================] - 0s 785us/step - loss: 0.4383 - accuracy: 0.8034
# Epoch 23/50
# 85/85 [==============================] - 0s 806us/step - loss: 0.4377 - accuracy: 0.8019
# Epoch 24/50
# 85/85 [==============================] - 0s 812us/step - loss: 0.4373 - accuracy: 0.8038
# Epoch 25/50
# 85/85 [==============================] - 0s 777us/step - loss: 0.4370 - accuracy: 0.8023
# Epoch 26/50
# 85/85 [==============================] - 0s 790us/step - loss: 0.4367 - accuracy: 0.8027
# Epoch 27/50
# 85/85 [==============================] - 0s 799us/step - loss: 0.4364 - accuracy: 0.8030
# Epoch 28/50
# 85/85 [==============================] - 0s 813us/step - loss: 0.4361 - accuracy: 0.8030
# Epoch 29/50
# 85/85 [==============================] - 0s 793us/step - loss: 0.4361 - accuracy: 0.8041
# Epoch 30/50
# 85/85 [==============================] - 0s 774us/step - loss: 0.4359 - accuracy: 0.8030
# Epoch 31/50
# 85/85 [==============================] - 0s 791us/step - loss: 0.4357 - accuracy: 0.8060
# Epoch 32/50
# 85/85 [==============================] - 0s 787us/step - loss: 0.4355 - accuracy: 0.8027
# Epoch 33/50
# 85/85 [==============================] - 0s 770us/step - loss: 0.4354 - accuracy: 0.8038
# Epoch 34/50
# 85/85 [==============================] - 0s 1ms/step - loss: 0.4353 - accuracy: 0.8049
# Epoch 35/50
# 85/85 [==============================] - 0s 813us/step - loss: 0.4351 - accuracy: 0.8049
# Epoch 36/50
# 85/85 [==============================] - 0s 809us/step - loss: 0.4340 - accuracy: 0.8038
# Epoch 37/50
# 85/85 [==============================] - 0s 776us/step - loss: 0.4337 - accuracy: 0.8049
# Epoch 38/50
# 85/85 [==============================] - 0s 805us/step - loss: 0.4335 - accuracy: 0.8019
# Epoch 39/50
# 85/85 [==============================] - 0s 792us/step - loss: 0.4331 - accuracy: 0.8041
# Epoch 40/50
# 85/85 [==============================] - 0s 807us/step - loss: 0.4329 - accuracy: 0.8060
# Epoch 41/50
# 85/85 [==============================] - 0s 790us/step - loss: 0.4326 - accuracy: 0.8023
# Epoch 42/50
# 85/85 [==============================] - 0s 791us/step - loss: 0.4324 - accuracy: 0.8049
# Epoch 43/50
# 85/85 [==============================] - 0s 795us/step - loss: 0.4320 - accuracy: 0.8041
# Epoch 44/50
# 85/85 [==============================] - 0s 812us/step - loss: 0.4318 - accuracy: 0.8034
# Epoch 45/50
# 85/85 [==============================] - 0s 831us/step - loss: 0.4313 - accuracy: 0.8034
# Epoch 46/50
# 85/85 [==============================] - 0s 801us/step - loss: 0.4312 - accuracy: 0.8027
# Epoch 47/50
# 85/85 [==============================] - 0s 790us/step - loss: 0.4308 - accuracy: 0.8045
# Epoch 48/50
# 85/85 [==============================] - 0s 785us/step - loss: 0.4308 - accuracy: 0.8027
# Epoch 49/50
# 85/85 [==============================] - 0s 778us/step - loss: 0.4303 - accuracy: 0.8034
# Epoch 50/50
# 85/85 [==============================] - 0s 773us/step - loss: 0.4302 - accuracy: 0.8038
# 25/25 [==============================] - 0s 785us/step

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.85      0.91       772
#            1       0.08      0.50      0.13        20
#
#     accuracy                           0.84       792
#    macro avg       0.53      0.67      0.52       792
# weighted avg       0.96      0.84      0.89       792

# %% [markdown]
# BernoulliNB parece ser el algoritmo que mejor performa, aunque hay mucho espacio para buscar mejoras.

# %% [markdown]
# Usamos Regresión Logistica para ver la importancia de los features

# %%
model=LogisticRegressionCV(scoring='f1')
    
model.fit(X_train_sm_sc, y_train_sm)
y_pred=model.predict(X_test_sm_sc)
y_proba=model.predict_proba(X_test_sm_sc)

print(classification_report(y_test,y_pred))

print('Area bajo la curva ROC:',np.round(roc_auc_score(y_test,y_proba[:,1]),4))

precision, recall,threshold=precision_recall_curve(y_test,y_proba[:,1]);

print('Area bajo la curva Precision-Recall:',np.round(auc(recall,precision),4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.87      0.92       772
#            1       0.09      0.50      0.15        20
#
#     accuracy                           0.86       792
#    macro avg       0.54      0.68      0.54       792
# weighted avg       0.96      0.86      0.90       792
#
# Area bajo la curva ROC: 0.8206
# Area bajo la curva Precision-Recall: 0.1207

# %%
model.n_features_in_
# Out:
# 4

# %%
X.columns
# Out:
# Index(['dias_hasta_primer_examen', 'nota_parcial', 'score',
#        'tiempo_hasta_submision'],
#       dtype='object')

# %%
model.coef_
# Out:
# array([[-0.02385422, -1.56879313, -0.10673112,  0.13278198]])

# %% [markdown]
# El orden de importancia de las features es:
# - nota_parcial
# - tiempo_hasta_submision
# - score
# - dias_hasta_primer_examen

# %% [markdown]
# ---
